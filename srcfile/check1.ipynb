# %%
#import appointment inperson file:

import pandas as pd
df = pd.read_excel(r"C:\Users\muthu\Downloads\Appointment _Inperson.xlsx")
df.info
# Out:
# <bound method DataFrame.info of     Appointment | My Website                           Unnamed: 1  \
# 0                          #                                 Name
# 1                         34  عبدالرحمن عبدالرحيم الفخري PFBCMLBN
# 2                         77  هلال سعد باكرموم KSA-15664 PFBCMLBN
# 3                         95               Bandar HesseinPFBCMLBN
# 4                        117        عبدالله احمد النزيلي PFBCMLBN
# ..                       ...                                  ...
# 715                      709                   ashif anasPFBCMLBN
# 716                      711           بندر خالد  الغنام PFBCMLBN
# 717                      713          Mohammed abdul-baqiPFBCMLBN
# 718                      714       Hassan Rajpoot khokar PFBCMLBN
# 719                      718            محمد علي القحطانيPFBCMLBN
#
#          Unnamed: 2  Unnamed: 3 Unnamed: 4          Unnamed: 5  \
# 0            Mobile  Patient ID     Gender         Salesperson
# ...
